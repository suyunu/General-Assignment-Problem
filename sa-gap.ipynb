# %% [markdown]
# # Simulated Annealing on General Assignment Problem
#
# In this project, we tried to solve General Assignment Problem (GAP) with Simulated Annealing (SA).
#
# ## General Assignment Problem
#
# There are a number of agents and a number of tasks. Any agent can be assigned to perform any task, incurring some cost. Moreover, each agent has a budget and the sum of the costs of tasks assigned to it cannot exceed this budget. It is required to find an assignment in which all agents do not exceed their budget and total cost of the assignment is minimized.
#
# ## Solution Representation
#
# To represent the solution, I used a simple list structure. Cells of the list are jobs and numbers in the cells are the agents assigned to that job.
#
# Example solution representation:
# [7, 1, 0, 4, 4, 2, 4, 1, 5, 6, 3, 4, 5, 5, 1, 5, 2, 1, 4, 0, 7, 7, 5, 7, 5, 2, 3, 0, 2, 1, 7, 6, 6, 7, 3, 4, 3, 6, 3, 6]
#
# ## Algorithm
#
# We used simulated annealing with some modification to solve General Assignment Problem. First, I will write the pseudocode of my simulated annealing and then try to explain important parts like neighborhood structure and stopping condition.
#
# ### Pseudocode
#
# <ol>
# <li>Compute an initial solution $X$ and choose an initial temprature $T>0$ and a repetition factor $L$</li>
# <li>As long as the stopping criterion is not satisfied perform the following steps:</li>
#     <ol>
#     <li>Do the following $L_k$ times</li>
#         <ol>
#         <li>Generate a random solution in the neighborhood $x' \in N(x)$.</li>
#         <li>Compute $\Delta = f(x') - f(x) + unfit(x')$ </li>
#         <li>Generate a random number $0<u<1$</li>
#         <li>If $\Delta<0$ or u < $e^{-\frac{\Delta}{T_k}}$ then set $x \gets x'$ </li>
#         <li>If $x$ is feasible and $f(x) < f(x^*)$ then set $x^* \gets x$</li>
#         </ol>
#     <li>Update $T_k$ and $L_k$</li>
#         <ol>
#         <li>$T_{k+1} \gets \alpha * T_k$</li>
#         <li>$L_{k+1} \gets \gamma * L_k$</li>
#         </ol>
#     </ol>
# <li>Report the incumbent solution</li>
# </ol>
#
# ### Important Functionalities
#
# In this part, I will explain important parts of the algorith. You can also find the corresponding function's name of the code next to each subsection name.
#
# #### First Solution Generation (generateSolution())
#
# This step generates the first solution for the algorithm. For the reason that SA is an improvement heuristic, we should generate an initial solution. I will explain it with the pseuodo code:
#
# <ol>
# <li>While no feasible solution found, loop 1000 times:</li>
#     <ol>
#     <li>Create a list of jobs and take a random permutation of it then iterate on the list:</li>
#         <ol>
#         <li>Find the agent with minimum resource consumption on this job and the agent whose resource limit not exceeded</li>
#             <ol>
#             <li>Assign the job to that user</li>
#             </ol>
#         <li>If there is no viable/feasible agent for a job, then break</li>
#         </ol>
#     </ol>
# <li>If no feasible solution found, then create a random assignment list.</li>
# </ol>
#
#
#
# #### Neigborhood Structure (findNeighbor(solution, nSize))
#
# I tried two different neigborhood structure. They are very similar actually.
# <ol>
# <li>Randomly change assignees of two randomly chosen jobs</li>
# <li>Randomly change assignees of three randomly chosen jobs</li>
# </ol>
#
# Actually in the code, the nSize parameter of findNeighbor(solution, nSize) function indicates the number of changes of neighbor structure.
#
#
# #### Unfitness of a Solution (calculateUnfit(solution))
#
# My simulated annealing algorithm can also accept infeasible solutions. However, to punish infeasible solutions, I used an unfitness score which I took from the GA on GAP paper. In short, the unfitness score calculated like this:
#
# $ u_k = \sum_{i \in I} max \left[0, \left(\sum_{j \in J, s_{kj} = i} r_{ij} \right) - b_i \right] $
#
# #### Initial Temperature (setInitialTemp(acceptProb, nSize))
#
# I used the method we learnt in the class. I calculated the first temperature from the initial acceptance probability.
#
# First, I calculated 10000 delta value which are difference between objective values of two neighbor solution. Then took the average of delta values. Then:
#
# $ T_1 = \frac{\left|\Delta_{bar}\right|}{\ln{\frac{1}{P_1}}} $
#
#
# #### Stopping Condition (stopCond(allSolutions, L))
#
# <ul>
# <li>Do not stop while $L < 10000$ </li>
# <li>If $L > 10000$ and $L < 50000$ then stop if the change in objective function of $10$ last solution is less than $0.1%$</li>
# <li>If $L > 50000$ and $L < 150000$ then stop if the change in objective function of $5$ last solution is less than $0.1%$</li>
# <li>If $L > 150000$ stop </li>
# </ul>

# %% [markdown]
# ### Importing important libraries

# %%
# %matplotlib inline

import numpy as np
import math
import time
import random
import pickle
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

# Enter your own plotly credentials to play on plots
plotly.tools.set_credentials_file(username='', api_key='')

# %% [markdown]
# ### Reading data
# Reading input from document and initializing variables.
# You can change dataset variable to 1, 2, 3 or 4 to use different input sets.

# %%
# Dataset number. 1, 2, 3 or 4
dataset = "4"

if dataset == "1":
    optimalObjective = 438
elif dataset == "2":
    optimalObjective = 646
elif dataset == "3":
    optimalObjective = 573
else:
    optimalObjective = 1698

filename = "gap-data-4instances" + dataset + ".txt"
f = open(filename, 'r')
l = f.readline().split()

# number of agents
m = int(l[0])

# number of jobs
n = int(l[1])

# cost of assigning job j to agent i
c = []

# resource required by agent i to perform job j
r = []

# resource capacity of agent i.
b = []


for i in range(m):
    temp = []
    for l in f.readline().split():
        temp.append(int(l))
    c.append(temp)
    
for i in range(m):
    temp = []
    for l in f.readline().split():
        temp.append(int(l))
    r.append(temp)

for l in f.readline().split():
    b.append(int(l))
    
f.close()

# %% [markdown]
# ### Helper Funtions
#
# Functions to be used in Simulated Annealing algorithm.

# %%
def isFeasible(solution):
    caps = [0] * m
    for i in range(len(solution)):
        caps[solution[i]] = caps[solution[i]] + r[solution[i]][i]
        
    for i in range(len(caps)):
        if b[i] < caps[i]:
            return False
        
    return True

def calculateCost(solution):
    cost = 0
    for i in range(len(solution)):
        cost = cost + c[solution[i]][i]
    
    return cost

def calculateUnfit(solution):
    unfitness = 0
    caps = [0] * m
    
    for i in range(len(solution)):
        caps[solution[i]] = caps[solution[i]] + r[solution[i]][i]
        
    for i in range(len(caps)):
        unfitness = unfitness + max(0, caps[i] - b[i])
    
    return unfitness

def generateSolution():
    solution = [0] * n
    
    for count in range(1000):
        isFound = True
        caps = [0] * m
        for job in np.random.permutation(n):
            minWork = sum(b)
            minWorker = -1
            for i in range(m):
                if caps[i]+r[i][job] <= b[i]:
                    if r[i][job] < minWork:
                        minWork = r[i][job]
                        minWorker = i
            if minWorker == -1:
                isFound = False
                break
            else:
                solution[job] = minWorker
                caps[minWorker] = caps[minWorker] + minWork
        
        if isFound == True:
            break
    
    if not isFound:
        for i in range(len(solution)):
            solution[i] = random.randint(0,m-1)
    
    return solution


def findNeighbor(solution, nSize):
    newSolution = list(solution)
    
    for i in range(nSize):
        k = random.randint(0,m*n-1)
        agent = int(k / n)
        job = k % n
        newSolution[job] = agent
        
    return newSolution
    
def setInitialTemp(acceptProb, nSize):
    deltaSum = 0
    for i in range(10000):
        solution = generateSolution()
        newSolution = findNeighbor(solution, nSize)
        deltaSum = deltaSum + abs(calculateCost(newSolution) - calculateCost(solution))
    
    return (deltaSum/10000) / math.log(1/acceptProb)


def stopCond(allSolutions, L):
    s = len(allSolutions)
    if L < 10000:
        return False
    if L > 150000:
        return True
    if L > 50000 and ((allSolutions[s-5] - allSolutions[s-1]) / allSolutions[s-5]) * 100 < 0.1:
        return True
    if ((allSolutions[s-10] - allSolutions[s-1]) / allSolutions[s-10]) * 100 > 0.1:
        return False
    
    
    return True
    
    
solution = generateSolution()
print(solution)
print(isFeasible(solution))

newSolution = findNeighbor(solution, 2)
print(newSolution)

print(calculateCost(solution))
print(calculateCost(newSolution))


#print(math.exp(-0.1/0.3))
# Out:
# [7, 1, 0, 4, 4, 2, 4, 1, 5, 6, 3, 4, 5, 5, 1, 5, 2, 1, 4, 0, 7, 7, 5, 7, 5, 2, 3, 0, 2, 1, 7, 6, 6, 7, 3, 4, 3, 6, 3, 6]
# True
# [7, 1, 0, 4, 4, 2, 4, 1, 0, 6, 3, 4, 5, 5, 1, 5, 2, 5, 4, 0, 7, 7, 5, 7, 5, 2, 3, 0, 2, 1, 7, 6, 6, 7, 3, 4, 3, 6, 3, 6]
# 819
# 817

# %%
print(setInitialTemp(0.80, 2))
# Out:
# 21.802557014741705

# %% [markdown]
# ### Main Simulated Annealing Code

# %%
# nReheat: How many times the algorithm will run with this parameters from the begining.
# bestSolutions: Holds all the incumbent solutions for each run.
# totalIterations: Number of total iterations for each run.

def SA_GAP(initialTemp, initialL, alpha, gama, nSize, nReheat, bestSolutions, totalIterations):
    Temp = initialTemp
    L = initialL
    allSolutions = []
    solution = generateSolution()
    
    bestSolution = []
    if isFeasible(solution):
        bestSolution = list(solution)
    
    reheated = True

    for rh in range(nReheat):
        t11 = time.clock()
        while not stopCond(allSolutions, L):
            if not reheated:
                if bestSolution == []:
                    solution = generateSolution()
                else:
                    solution = list(bestSolution)
            else:
                reheated = False

            for i in range(L):
                newSolution = findNeighbor(solution, nSize)
                u = np.random.uniform(0,1)
                deltaCost = calculateCost(newSolution) - calculateCost(solution) + calculateUnfit(newSolution)

                if deltaCost < 0 or u < math.exp(-deltaCost/(Temp)):
                    solution = list(newSolution)
                if isFeasible(newSolution) and  (bestSolution == [] or calculateCost(newSolution) < calculateCost(bestSolution)):
                    bestSolution = list(newSolution)


            Temp = Temp * alpha
            L = int(L * gama)
            allSolutions.append(calculateCost(bestSolution))
            #print(str(len(allSolutions)) + ' - ' + str(math.exp(-deltaCost/(Temp))) + ' - ' + str(L) + ' - ' + str(calculateCost(bestSolution)) + ' - ' + str(calculateCost(solution)))
            
        t22 = time.clock()
        bestSolutions.append(bestSolution)
        totalIterations.append(len(allSolutions))
        
        bSolVal = calculateCost(bestSolution)
        G = 100 * (bSolVal-optimalObjective) / optimalObjective
        nCycle = len(allSolutions)
        timePassed = t22-t11
        print("Objective Value: " + str(bSolVal) + " - %Gap: " + "%.2f" %G + " - No. of Cycles: " + "%.2f" %nCycle +" - CPU Time(s): " + "%.2f" %timePassed)

        allSolutions = []
        Temp = initialTemp
        L = initialL
        solution = generateSolution()
        bestSolution = []
        if isFeasible(solution):
            bestSolution = list(solution)
        reheated = True

# %% [markdown]
# ## Hyperparameter Optimization
#
# After coding a working and partially efficient simulated annealing algortihm, the process turns into a hyperparameter optimization problem. Because in simulated annealing, there are lots of parameters you need to decide on and all of them effect can effect both the quality of output and time spent. So, after trying lots of combinations and taking notes on them, I actaully got very confused and decided to make a automated system which will run the code several times with different parameters.
#
# I determined some values for each parameter and run the code 5 times for each adjustment for each dataset. After each run I took objective values, %Gap values, number of cycles and run times for statistics.
#
# We ran the hyperparameter optimization on dataset 2. It actually was going to take more than 8 hours to complete, so to avoid this situation, when we encounter a configuration which gives worse than 2% gap in any run then we discard this configuration. With this method, it took nearly 3 hours to complete.
#
# Because it took so long to complete, I ran the code in two parts, first one for 2-change move operator and second one for 3-change move operator.
#
# ** Important Note: It takes too long to run the optimization part. Because of that, I saved the output of the optimization parts into two files. You can load them via the code below the optimization part. **

# %%
# Hyperparameter runs for 2-change move

runs = 5

nSizes = [2]

initialProbs = [0.75, 0.85, 0.95]

initialLs = [100, 500, 1000]

alphas = [0.85, 0.90, 0.95]

gamas = [1.05, 1.1, 1.15]

hyperParameters = []

counter = 1

for nSize in nSizes:
    for initialProb in initialProbs:
        for initialL in initialLs:
            for alpha in alphas:
                for gama in gamas:
                    hp = []
                    gapSum = 0
                    isOK = True
                    
                    print("(" + str(counter) + ") nSize: " + str(nSize) + " - Acceptance: " + str(initialProb) + " - L: " + str(initialL) + " - alpha: " + str(alpha) + " - gama: " + str(gama))
                    for run in range(runs):
                        t1 = time.clock()

                        bestSolutions = []
                        totalIterations = []

                        initialTemp = setInitialTemp(initialProb, nSize)
                        
                        SA_GAP(initialTemp, initialL, alpha, gama, nSize, 1, bestSolutions, totalIterations)

                        t2 = time.clock()

                        bSolVal = calculateCost(bestSolutions[0])
                        G = 100 * (bSolVal-optimalObjective) / optimalObjective
                        nCycle = totalIterations[0]
                        timePassed = t2-t1

                        print(str(run) + ". Objective Value: " + str(bSolVal) + " - %Gap: " + "%.2f" %G + " - No. of Cycles: " + "%.2f" %nCycle +" - CPU Time(s): " + "%.2f" %timePassed)
                        
                        hp.append([bSolVal, G, nCycle, timePassed])
                        gapSum = gapSum + G
                        
                        if G > 2:
                            isOK = False
                            break
                        
                    if isOK:
                        hyperParameters.append([hp,counter])
                    else:
                        print("DISCARD")
                    
                    counter = counter + 1
                    print()
# Out:
# (1) nSize: 2 - Acceptance: 0.75 - L: 100 - alpha: 0.85 - gama: 1.05
# 0. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 101.00 - CPU Time(s): 11.18
# 1. Objective Value: 659 - %Gap: 2.01 - No. of Cycles: 97.00 - CPU Time(s): 9.29
# DISCARD
#
# (2) nSize: 2 - Acceptance: 0.75 - L: 100 - alpha: 0.85 - gama: 1.1
# 0. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 66.00 - CPU Time(s): 19.46
# 1. Objective Value: 662 - %Gap: 2.48 - No. of Cycles: 57.00 - CPU Time(s): 9.18
# DISCARD
#
# (3) nSize: 2 - Acceptance: 0.75 - L: 100 - alpha: 0.85 - gama: 1.15
# 0. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 45.00 - CPU Time(s): 13.37
# 1. Objective Value: 659 - %Gap: 2.01 - No. of Cycles: 39.00 - CPU Time(s): 6.49
# DISCARD
#
# (4) nSize: 2 - Acceptance: 0.75 - L: 100 - alpha: 0.9 - gama: 1.05
# 0. Objective Value: 659 - %Gap: 2.01 - No. of Cycles: 97.00 - CPU Time(s): 8.53
# DISCARD
#
# (5) nSize: 2 - Acceptance: 0.75 - L: 100 - alpha: 0.9 - gama: 1.1
# 0. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 49.00 - CPU Time(s): 4.95
# 1. Objective Value: 662 - %Gap: 2.48 - No. of Cycles: 49.00 - CPU Time(s): 5.02
# DISCARD
#
# (6) nSize: 2 - Acceptance: 0.75 - L: 100 - alpha: 0.9 - gama: 1.15
# 0. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 45.00 - CPU Time(s): 13.66
# 1. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 45.00 - CPU Time(s): 14.02
# 2. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 45.00 - CPU Time(s): 13.89
# 3. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 48.00 - CPU Time(s): 19.52
# 4. Objective Value: 649 - %Gap: 0.46 - No. of Cycles: 42.00 - CPU Time(s): 9.20
#
# (7) nSize: 2 - Acceptance: 0.75 - L: 100 - alpha: 0.95 - gama: 1.05
# 0. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 103.00 - CPU Time(s): 10.88
# 1. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 97.00 - CPU Time(s): 8.47
# 2. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 97.00 - CPU Time(s): 8.48
# 3. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 97.00 - CPU Time(s): 8.45
# 4. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 106.00 - CPU Time(s): 12.41
#
# (8) nSize: 2 - Acceptance: 0.75 - L: 100 - alpha: 0.95 - gama: 1.1
# 0. Objective Value: 646 - %Gap: 0.00 - No. of Cycles: 68.00 - CPU Time(s): 23.06
# 1. Objective Value: 648 - %Gap: 0.31 - No. of Cycles: 66.00 - CPU Time(s): 19.30
# 2. Objective Value: 647 - %Gap: 0.15 - No. of Cycles: 66.00 - CPU Time(s): 19.20
# 3. Objective Value: 649 - %Gap: 0.46 - No. of Cycles: 66.00 - CPU Time(s): 19.24
# 4. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 66.00 - CPU Time(s): 19.19
#
# (9) nSize: 2 - Acceptance: 0.75 - L: 100 - alpha: 0.95 - gama: 1.15
# 0. Objective Value: 661 - %Gap: 2.32 - No. of Cycles: 45.00 - CPU Time(s): 13.16
# DISCARD
#
# (10) nSize: 2 - Acceptance: 0.75 - L: 500 - alpha: 0.85 - gama: 1.05
# 0. Objective Value: 660 - %Gap: 2.17 - No. of Cycles: 62.00 - CPU Time(s): 8.00
# DISCARD
#
# (11) nSize: 2 - Acceptance: 0.75 - L: 500 - alpha: 0.85 - gama: 1.1
# 0. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 38.00 - CPU Time(s): 7.67
# 1. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 56.00 - CPU Time(s): 40.76
# 2. Objective Value: 658 - %Gap: 1.86 - No. of Cycles: 43.00 - CPU Time(s): 14.96
# 3. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 32.00 - CPU Time(s): 6.26
# 4. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 42.00 - CPU Time(s): 13.29
#
# (12) nSize: 2 - Acceptance: 0.75 - L: 500 - alpha: 0.85 - gama: 1.15
# 0. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 36.00 - CPU Time(s): 24.08
# 1. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 29.00 - CPU Time(s): 10.08
# 2. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 33.00 - CPU Time(s): 16.73
# 3. Objective Value: 659 - %Gap: 2.01 - No. of Cycles: 26.00 - CPU Time(s): 6.39
# DISCARD
#
# (13) nSize: 2 - Acceptance: 0.75 - L: 500 - alpha: 0.9 - gama: 1.05
# 0. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 63.00 - CPU Time(s): 9.48
# 1. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 64.00 - CPU Time(s): 9.96
# 2. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 63.00 - CPU Time(s): 9.75
# 3. Objective Value: 661 - %Gap: 2.32 - No. of Cycles: 62.00 - CPU Time(s): 9.11
# DISCARD
#
# (14) nSize: 2 - Acceptance: 0.75 - L: 500 - alpha: 0.9 - gama: 1.1
# 0. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 49.00 - CPU Time(s): 23.16
# 1. Objective Value: 646 - %Gap: 0.00 - No. of Cycles: 52.00 - CPU Time(s): 27.97
# 2. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 48.00 - CPU Time(s): 19.69
# 3. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 37.00 - CPU Time(s): 7.82
# 4. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 49.00 - CPU Time(s): 21.02
#
# (15) nSize: 2 - Acceptance: 0.75 - L: 500 - alpha: 0.9 - gama: 1.15
# 0. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 36.00 - CPU Time(s): 20.14
# 1. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 35.00 - CPU Time(s): 17.82
# 2. Objective Value: 658 - %Gap: 1.86 - No. of Cycles: 33.00 - CPU Time(s): 13.62
# 3. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 37.00 - CPU Time(s): 27.52
# 4. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 33.00 - CPU Time(s): 15.13
#
# (16) nSize: 2 - Acceptance: 0.75 - L: 500 - alpha: 0.95 - gama: 1.05
# 0. Objective Value: 658 - %Gap: 1.86 - No. of Cycles: 62.00 - CPU Time(s): 9.61
# 1. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 89.00 - CPU Time(s): 30.70
# 2. Objective Value: 647 - %Gap: 0.15 - No. of Cycles: 76.00 - CPU Time(s): 16.07
# 3. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 79.00 - CPU Time(s): 18.50
# 4. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 62.00 - CPU Time(s): 8.69
#
# (17) nSize: 2 - Acceptance: 0.75 - L: 500 - alpha: 0.95 - gama: 1.1
# 0. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 49.00 - CPU Time(s): 23.17
# 1. Objective Value: 672 - %Gap: 4.02 - No. of Cycles: 37.00 - CPU Time(s): 7.92
# DISCARD
#
# (18) nSize: 2 - Acceptance: 0.75 - L: 500 - alpha: 0.95 - gama: 1.15
# 0. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 41.00 - CPU Time(s): 39.93
# 1. Objective Value: 659 - %Gap: 2.01 - No. of Cycles: 38.00 - CPU Time(s): 26.45
# DISCARD
#
# (19) nSize: 2 - Acceptance: 0.75 - L: 1000 - alpha: 0.85 - gama: 1.05
# 0. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 48.00 - CPU Time(s): 8.57
# 1. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 49.00 - CPU Time(s): 9.01
# 2. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 51.00 - CPU Time(s): 9.93
# 3. Objective Value: 649 - %Gap: 0.46 - No. of Cycles: 48.00 - CPU Time(s): 8.56
# 4. Objective Value: 658 - %Gap: 1.86 - No. of Cycles: 48.00 - CPU Time(s): 8.52
#
# (20) nSize: 2 - Acceptance: 0.75 - L: 1000 - alpha: 0.85 - gama: 1.1
# 0. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 35.00 - CPU Time(s): 11.86
# 1. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 35.00 - CPU Time(s): 12.01
# 2. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 32.00 - CPU Time(s): 9.19
# 3. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 37.00 - CPU Time(s): 14.43
# 4. Objective Value: 661 - %Gap: 2.32 - No. of Cycles: 36.00 - CPU Time(s): 13.12
# DISCARD
#
# (21) nSize: 2 - Acceptance: 0.75 - L: 1000 - alpha: 0.85 - gama: 1.15
# 0. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 35.00 - CPU Time(s): 36.59
# 1. Objective Value: 659 - %Gap: 2.01 - No. of Cycles: 29.00 - CPU Time(s): 16.99
# DISCARD
#
# (22) nSize: 2 - Acceptance: 0.75 - L: 1000 - alpha: 0.9 - gama: 1.05
# 0. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 54.00 - CPU Time(s): 11.19
# 1. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 52.00 - CPU Time(s): 10.50
# 2. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 48.00 - CPU Time(s): 8.84
# 3. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 48.00 - CPU Time(s): 8.88
# 4. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 64.00 - CPU Time(s): 18.18
#
# (23) nSize: 2 - Acceptance: 0.75 - L: 1000 - alpha: 0.9 - gama: 1.1
# 0. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 45.00 - CPU Time(s): 29.16
# 1. Objective Value: 646 - %Gap: 0.00 - No. of Cycles: 42.00 - CPU Time(s): 22.47
# 2. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 35.00 - CPU Time(s): 12.13
# 3. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 42.00 - CPU Time(s): 22.50
# 4. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 38.00 - CPU Time(s): 15.78
#
# (24) nSize: 2 - Acceptance: 0.75 - L: 1000 - alpha: 0.9 - gama: 1.15
# 0. Objective Value: 646 - %Gap: 0.00 - No. of Cycles: 36.00 - CPU Time(s): 42.72
# 1. Objective Value: 647 - %Gap: 0.15 - No. of Cycles: 36.00 - CPU Time(s): 46.13
# 2. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 30.00 - CPU Time(s): 19.63
# 3. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 31.00 - CPU Time(s): 22.61
# 4. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 35.00 - CPU Time(s): 37.22
#
# (25) nSize: 2 - Acceptance: 0.75 - L: 1000 - alpha: 0.95 - gama: 1.05
# 0. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 58.00 - CPU Time(s): 13.73
# 1. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 61.00 - CPU Time(s): 15.88
# 2. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 69.00 - CPU Time(s): 24.04
# 3. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 66.00 - CPU Time(s): 19.97
# 4. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 75.00 - CPU Time(s): 30.86
#
# (26) nSize: 2 - Acceptance: 0.75 - L: 1000 - alpha: 0.95 - gama: 1.1
# 0. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 46.00 - CPU Time(s): 33.02
# 1. Objective Value: 658 - %Gap: 1.86 - No. of Cycles: 47.00 - CPU Time(s): 35.22
# 2. Objective Value: 660 - %Gap: 2.17 - No. of Cycles: 46.00 - CPU Time(s): 32.69
# DISCARD
#
# (27) nSize: 2 - Acceptance: 0.75 - L: 1000 - alpha: 0.95 - gama: 1.15
# 0. Objective Value: 662 - %Gap: 2.48 - No. of Cycles: 36.00 - CPU Time(s): 41.51
# DISCARD
#
# (28) nSize: 2 - Acceptance: 0.85 - L: 100 - alpha: 0.85 - gama: 1.05
# 0. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 108.00 - CPU Time(s): 15.47
# 1. Objective Value: 664 - %Gap: 2.79 - No. of Cycles: 97.00 - CPU Time(s): 10.49
# DISCARD
#
# (29) nSize: 2 - Acceptance: 0.85 - L: 100 - alpha: 0.85 - gama: 1.1
# 0. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 50.00 - CPU Time(s): 6.10
# 1. Objective Value: 660 - %Gap: 2.17 - No. of Cycles: 49.00 - CPU Time(s): 5.50
# DISCARD
#
# (30) nSize: 2 - Acceptance: 0.85 - L: 100 - alpha: 0.85 - gama: 1.15
# 0. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 42.00 - CPU Time(s): 10.38
# 1. Objective Value: 659 - %Gap: 2.01 - No. of Cycles: 53.00 - CPU Time(s): 43.01
# DISCARD
#
# (31) nSize: 2 - Acceptance: 0.85 - L: 100 - alpha: 0.9 - gama: 1.05
# 0. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 97.00 - CPU Time(s): 9.71
# 1. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 97.00 - CPU Time(s): 9.80
# 2. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 105.00 - CPU Time(s): 13.79
# 3. Objective Value: 658 - %Gap: 1.86 - No. of Cycles: 105.00 - CPU Time(s): 13.57
# 4. Objective Value: 663 - %Gap: 2.63 - No. of Cycles: 97.00 - CPU Time(s): 9.79
# DISCARD
#
# (32) nSize: 2 - Acceptance: 0.85 - L: 100 - alpha: 0.9 - gama: 1.1
# 0. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 58.00 - CPU Time(s): 11.05
# 1. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 66.00 - CPU Time(s): 22.23
# 2. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 57.00 - CPU Time(s): 10.09
# 3. Objective Value: 661 - %Gap: 2.32 - No. of Cycles: 56.00 - CPU Time(s): 9.27
# DISCARD
#
# (33) nSize: 2 - Acceptance: 0.85 - L: 100 - alpha: 0.9 - gama: 1.15
# 0. Objective Value: 662 - %Gap: 2.48 - No. of Cycles: 42.00 - CPU Time(s): 10.62
# DISCARD
#
# (34) nSize: 2 - Acceptance: 0.85 - L: 100 - alpha: 0.95 - gama: 1.05
# 0. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 97.00 - CPU Time(s): 9.63
# 1. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 97.00 - CPU Time(s): 9.75
# 2. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 111.00 - CPU Time(s): 18.07
# 3. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 97.00 - CPU Time(s): 11.87
# 4. Objective Value: 660 - %Gap: 2.17 - No. of Cycles: 97.00 - CPU Time(s): 11.12
# DISCARD
#
# (35) nSize: 2 - Acceptance: 0.85 - L: 100 - alpha: 0.95 - gama: 1.1
# 0. Objective Value: 670 - %Gap: 3.72 - No. of Cycles: 49.00 - CPU Time(s): 6.17
# DISCARD
#
# (36) nSize: 2 - Acceptance: 0.85 - L: 100 - alpha: 0.95 - gama: 1.15
# 0. Objective Value: 668 - %Gap: 3.41 - No. of Cycles: 49.00 - CPU Time(s): 24.59
# DISCARD
#
# (37) nSize: 2 - Acceptance: 0.85 - L: 500 - alpha: 0.85 - gama: 1.05
# 0. Objective Value: 660 - %Gap: 2.17 - No. of Cycles: 62.00 - CPU Time(s): 9.44
# DISCARD
#
# (38) nSize: 2 - Acceptance: 0.85 - L: 500 - alpha: 0.85 - gama: 1.1
# 0. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 36.00 - CPU Time(s): 7.61
# 1. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 43.00 - CPU Time(s): 14.52
# 2. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 49.00 - CPU Time(s): 24.64
# 3. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 47.00 - CPU Time(s): 20.03
# 4. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 41.00 - CPU Time(s): 13.47
#
# (39) nSize: 2 - Acceptance: 0.85 - L: 500 - alpha: 0.85 - gama: 1.15
# 0. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 33.00 - CPU Time(s): 15.59
# 1. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 33.00 - CPU Time(s): 16.91
# 2. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 34.00 - CPU Time(s): 18.83
# 3. Objective Value: 647 - %Gap: 0.15 - No. of Cycles: 38.00 - CPU Time(s): 29.19
# 4. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 32.00 - CPU Time(s): 13.73
#
# (40) nSize: 2 - Acceptance: 0.85 - L: 500 - alpha: 0.9 - gama: 1.05
# 0. Objective Value: 659 - %Gap: 2.01 - No. of Cycles: 62.00 - CPU Time(s): 9.82
# DISCARD
#
# (41) nSize: 2 - Acceptance: 0.85 - L: 500 - alpha: 0.9 - gama: 1.1
# 0. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 50.00 - CPU Time(s): 25.57
# 1. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 49.00 - CPU Time(s): 22.29
# 2. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 50.00 - CPU Time(s): 23.73
# 3. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 48.00 - CPU Time(s): 19.70
# 4. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 49.00 - CPU Time(s): 21.62
#
# (42) nSize: 2 - Acceptance: 0.85 - L: 500 - alpha: 0.9 - gama: 1.15
# 0. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 37.00 - CPU Time(s): 23.60
# 1. Objective Value: 647 - %Gap: 0.15 - No. of Cycles: 35.00 - CPU Time(s): 18.27
# 2. Objective Value: 659 - %Gap: 2.01 - No. of Cycles: 34.00 - CPU Time(s): 15.96
# DISCARD
#
# (43) nSize: 2 - Acceptance: 0.85 - L: 500 - alpha: 0.95 - gama: 1.05
# 0. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 73.00 - CPU Time(s): 14.45
# 1. Objective Value: 658 - %Gap: 1.86 - No. of Cycles: 62.00 - CPU Time(s): 9.05
# 2. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 81.00 - CPU Time(s): 21.04
# 3. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 63.00 - CPU Time(s): 9.33
# 4. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 82.00 - CPU Time(s): 22.48
#
# (44) nSize: 2 - Acceptance: 0.85 - L: 500 - alpha: 0.95 - gama: 1.1
# 0. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 60.00 - CPU Time(s): 61.00
# 1. Objective Value: 663 - %Gap: 2.63 - No. of Cycles: 49.00 - CPU Time(s): 22.13
# DISCARD
#
# (45) nSize: 2 - Acceptance: 0.85 - L: 500 - alpha: 0.95 - gama: 1.15
# 0. Objective Value: 671 - %Gap: 3.87 - No. of Cycles: 41.00 - CPU Time(s): 40.23
# DISCARD
#
# (46) nSize: 2 - Acceptance: 0.85 - L: 1000 - alpha: 0.85 - gama: 1.05
# 0. Objective Value: 658 - %Gap: 1.86 - No. of Cycles: 48.00 - CPU Time(s): 8.71
# 1. Objective Value: 658 - %Gap: 1.86 - No. of Cycles: 48.00 - CPU Time(s): 8.71
# 2. Objective Value: 663 - %Gap: 2.63 - No. of Cycles: 53.00 - CPU Time(s): 10.85
# DISCARD
#
# (47) nSize: 2 - Acceptance: 0.85 - L: 1000 - alpha: 0.85 - gama: 1.1
# 0. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 47.00 - CPU Time(s): 35.72
# 1. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 40.00 - CPU Time(s): 19.10
# 2. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 42.00 - CPU Time(s): 24.74
# 3. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 38.00 - CPU Time(s): 16.96
# 4. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 42.00 - CPU Time(s): 23.03
#
# (48) nSize: 2 - Acceptance: 0.85 - L: 1000 - alpha: 0.85 - gama: 1.15
# 0. Objective Value: 658 - %Gap: 1.86 - No. of Cycles: 36.00 - CPU Time(s): 43.15
# 1. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 33.00 - CPU Time(s): 28.24
# 2. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 29.00 - CPU Time(s): 16.74
# 3. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 29.00 - CPU Time(s): 17.01
# 4. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 32.00 - CPU Time(s): 24.93
#
# (49) nSize: 2 - Acceptance: 0.85 - L: 1000 - alpha: 0.9 - gama: 1.05
# 0. Objective Value: 661 - %Gap: 2.32 - No. of Cycles: 48.00 - CPU Time(s): 9.69
# DISCARD
#
# (50) nSize: 2 - Acceptance: 0.85 - L: 1000 - alpha: 0.9 - gama: 1.1
# 0. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 42.00 - CPU Time(s): 23.47
# 1. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 47.00 - CPU Time(s): 37.71
# 2. Objective Value: 647 - %Gap: 0.15 - No. of Cycles: 43.00 - CPU Time(s): 26.70
# 3. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 42.00 - CPU Time(s): 23.70
# 4. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 42.00 - CPU Time(s): 24.66
#
# (51) nSize: 2 - Acceptance: 0.85 - L: 1000 - alpha: 0.9 - gama: 1.15
# 0. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 36.00 - CPU Time(s): 45.13
# 1. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 36.00 - CPU Time(s): 43.17
# 2. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 36.00 - CPU Time(s): 43.23
# 3. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 34.00 - CPU Time(s): 32.94
# 4. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 36.00 - CPU Time(s): 44.64
#
# (52) nSize: 2 - Acceptance: 0.85 - L: 1000 - alpha: 0.95 - gama: 1.05
# 0. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 72.00 - CPU Time(s): 29.56
# 1. Objective Value: 649 - %Gap: 0.46 - No. of Cycles: 81.00 - CPU Time(s): 47.47
# 2. Objective Value: 661 - %Gap: 2.32 - No. of Cycles: 60.00 - CPU Time(s): 17.62
# DISCARD
#
# (53) nSize: 2 - Acceptance: 0.85 - L: 1000 - alpha: 0.95 - gama: 1.1
# 0. Objective Value: 666 - %Gap: 3.10 - No. of Cycles: 46.00 - CPU Time(s): 34.22
# DISCARD
#
# (54) nSize: 2 - Acceptance: 0.85 - L: 1000 - alpha: 0.95 - gama: 1.15
# 0. Objective Value: 727 - %Gap: 12.54 - No. of Cycles: 30.00 - CPU Time(s): 18.42
# DISCARD
#
# (55) nSize: 2 - Acceptance: 0.95 - L: 100 - alpha: 0.85 - gama: 1.05
# 0. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 101.00 - CPU Time(s): 12.23
# 1. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 97.00 - CPU Time(s): 9.81
# 2. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 123.00 - CPU Time(s): 32.01
# 3. Objective Value: 658 - %Gap: 1.86 - No. of Cycles: 97.00 - CPU Time(s): 10.04
# 4. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 129.00 - CPU Time(s): 44.04
#
# (56) nSize: 2 - Acceptance: 0.95 - L: 100 - alpha: 0.85 - gama: 1.1
# 0. Objective Value: 663 - %Gap: 2.63 - No. of Cycles: 49.00 - CPU Time(s): 5.77
# DISCARD
#
# (57) nSize: 2 - Acceptance: 0.95 - L: 100 - alpha: 0.85 - gama: 1.15
# 0. Objective Value: 666 - %Gap: 3.10 - No. of Cycles: 35.00 - CPU Time(s): 5.10
# DISCARD
#
# (58) nSize: 2 - Acceptance: 0.95 - L: 100 - alpha: 0.9 - gama: 1.05
# 0. Objective Value: 662 - %Gap: 2.48 - No. of Cycles: 97.00 - CPU Time(s): 10.01
# DISCARD
#
# (59) nSize: 2 - Acceptance: 0.95 - L: 100 - alpha: 0.9 - gama: 1.1
# 0. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 59.00 - CPU Time(s): 11.82
# 1. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 53.00 - CPU Time(s): 7.49
# 2. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 53.00 - CPU Time(s): 7.91
# 3. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 67.00 - CPU Time(s): 25.40
# 4. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 62.00 - CPU Time(s): 16.46
#
# (60) nSize: 2 - Acceptance: 0.95 - L: 100 - alpha: 0.9 - gama: 1.15
# 0. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 53.00 - CPU Time(s): 44.07
# 1. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 50.00 - CPU Time(s): 30.45
# 2. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 50.00 - CPU Time(s): 31.09
# 3. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 50.00 - CPU Time(s): 34.12
# 4. Objective Value: 659 - %Gap: 2.01 - No. of Cycles: 45.00 - CPU Time(s): 17.26
# DISCARD
#
# (61) nSize: 2 - Acceptance: 0.95 - L: 100 - alpha: 0.95 - gama: 1.05
# 0. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 97.00 - CPU Time(s): 11.54
# 1. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 98.00 - CPU Time(s): 12.28
# 2. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 106.00 - CPU Time(s): 17.49
# 3. Objective Value: 658 - %Gap: 1.86 - No. of Cycles: 97.00 - CPU Time(s): 12.93
# 4. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 113.00 - CPU Time(s): 22.60
#
# (62) nSize: 2 - Acceptance: 0.95 - L: 100 - alpha: 0.95 - gama: 1.1
# 0. Objective Value: 667 - %Gap: 3.25 - No. of Cycles: 68.00 - CPU Time(s): 30.76
# DISCARD
#
# (63) nSize: 2 - Acceptance: 0.95 - L: 100 - alpha: 0.95 - gama: 1.15
# 0. Objective Value: 771 - %Gap: 19.35 - No. of Cycles: 40.00 - CPU Time(s): 10.25
# DISCARD
#
# (64) nSize: 2 - Acceptance: 0.95 - L: 500 - alpha: 0.85 - gama: 1.05
# 0. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 69.00 - CPU Time(s): 14.33
# 1. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 71.00 - CPU Time(s): 14.28
# 2. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 76.00 - CPU Time(s): 18.45
# 3. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 87.00 - CPU Time(s): 30.00
# 4. Objective Value: 661 - %Gap: 2.32 - No. of Cycles: 62.00 - CPU Time(s): 10.08
# DISCARD
#
# (65) nSize: 2 - Acceptance: 0.95 - L: 500 - alpha: 0.85 - gama: 1.1
# 0. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 48.00 - CPU Time(s): 21.34
# 1. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 43.00 - CPU Time(s): 13.40
# 2. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 45.00 - CPU Time(s): 16.14
# 3. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 47.00 - CPU Time(s): 20.08
# 4. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 47.00 - CPU Time(s): 19.91
#
# (66) nSize: 2 - Acceptance: 0.95 - L: 500 - alpha: 0.85 - gama: 1.15
# 0. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 40.00 - CPU Time(s): 36.38
# 1. Objective Value: 660 - %Gap: 2.17 - No. of Cycles: 41.00 - CPU Time(s): 41.74
# DISCARD
#
# (67) nSize: 2 - Acceptance: 0.95 - L: 500 - alpha: 0.9 - gama: 1.05
# 0. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 74.00 - CPU Time(s): 16.34
# 1. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 62.00 - CPU Time(s): 9.46
# 2. Objective Value: 659 - %Gap: 2.01 - No. of Cycles: 66.00 - CPU Time(s): 11.66
# DISCARD
#
# (68) nSize: 2 - Acceptance: 0.95 - L: 500 - alpha: 0.9 - gama: 1.1
# 0. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 51.00 - CPU Time(s): 26.81
# 1. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 49.00 - CPU Time(s): 22.35
# 2. Objective Value: 659 - %Gap: 2.01 - No. of Cycles: 49.00 - CPU Time(s): 22.21
# DISCARD
#
# (69) nSize: 2 - Acceptance: 0.95 - L: 500 - alpha: 0.9 - gama: 1.15
# 0. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 41.00 - CPU Time(s): 42.00
# 1. Objective Value: 795 - %Gap: 23.07 - No. of Cycles: 22.00 - CPU Time(s): 4.19
# DISCARD
#
# (70) nSize: 2 - Acceptance: 0.95 - L: 500 - alpha: 0.95 - gama: 1.05
# 0. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 95.00 - CPU Time(s): 40.37
# 1. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 95.00 - CPU Time(s): 42.37
# 2. Objective Value: 649 - %Gap: 0.46 - No. of Cycles: 95.00 - CPU Time(s): 41.72
# 3. Objective Value: 661 - %Gap: 2.32 - No. of Cycles: 95.00 - CPU Time(s): 41.60
# DISCARD
#
# (71) nSize: 2 - Acceptance: 0.95 - L: 500 - alpha: 0.95 - gama: 1.1
# 0. Objective Value: 683 - %Gap: 5.73 - No. of Cycles: 60.00 - CPU Time(s): 62.54
# DISCARD
#
# (72) nSize: 2 - Acceptance: 0.95 - L: 500 - alpha: 0.95 - gama: 1.15
# 0. Objective Value: 772 - %Gap: 19.50 - No. of Cycles: 22.00 - CPU Time(s): 4.22
# DISCARD
#
# (73) nSize: 2 - Acceptance: 0.95 - L: 1000 - alpha: 0.85 - gama: 1.05
# 0. Objective Value: 661 - %Gap: 2.32 - No. of Cycles: 54.00 - CPU Time(s): 11.57
# DISCARD
#
# (74) nSize: 2 - Acceptance: 0.95 - L: 1000 - alpha: 0.85 - gama: 1.1
# 0. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 38.00 - CPU Time(s): 15.81
# 1. Objective Value: 661 - %Gap: 2.32 - No. of Cycles: 42.00 - CPU Time(s): 22.55
# DISCARD
#
# (75) nSize: 2 - Acceptance: 0.95 - L: 1000 - alpha: 0.85 - gama: 1.15
# 0. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 31.00 - CPU Time(s): 21.39
# 1. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 36.00 - CPU Time(s): 42.44
# 2. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 34.00 - CPU Time(s): 32.40
# 3. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 29.00 - CPU Time(s): 16.44
# 4. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 34.00 - CPU Time(s): 33.31
#
# (76) nSize: 2 - Acceptance: 0.95 - L: 1000 - alpha: 0.9 - gama: 1.05
# 0. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 71.00 - CPU Time(s): 25.53
# 1. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 58.00 - CPU Time(s): 14.14
# 2. Objective Value: 646 - %Gap: 0.00 - No. of Cycles: 69.00 - CPU Time(s): 23.31
# 3. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 62.00 - CPU Time(s): 17.38
# 4. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 53.00 - CPU Time(s): 11.46
#
# (77) nSize: 2 - Acceptance: 0.95 - L: 1000 - alpha: 0.9 - gama: 1.1
# 0. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 47.00 - CPU Time(s): 37.54
# 1. Objective Value: 647 - %Gap: 0.15 - No. of Cycles: 50.00 - CPU Time(s): 47.29
# 2. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 46.00 - CPU Time(s): 32.93
# 3. Objective Value: 658 - %Gap: 1.86 - No. of Cycles: 42.00 - CPU Time(s): 22.81
# 4. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 45.00 - CPU Time(s): 31.09
#
# (78) nSize: 2 - Acceptance: 0.95 - L: 1000 - alpha: 0.9 - gama: 1.15
# 0. Objective Value: 664 - %Gap: 2.79 - No. of Cycles: 36.00 - CPU Time(s): 43.02
# DISCARD
#
# (79) nSize: 2 - Acceptance: 0.95 - L: 1000 - alpha: 0.95 - gama: 1.05
# 0. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 81.00 - CPU Time(s): 41.45
# 1. Objective Value: 648 - %Gap: 0.31 - No. of Cycles: 90.00 - CPU Time(s): 65.81
# 2. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 90.00 - CPU Time(s): 65.21
# 3. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 81.00 - CPU Time(s): 42.77
# 4. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 84.00 - CPU Time(s): 49.42
#
# (80) nSize: 2 - Acceptance: 0.95 - L: 1000 - alpha: 0.95 - gama: 1.1
# 0. Objective Value: 756 - %Gap: 17.03 - No. of Cycles: 25.00 - CPU Time(s): 5.74
# DISCARD
#
# (81) nSize: 2 - Acceptance: 0.95 - L: 1000 - alpha: 0.95 - gama: 1.15
# 0. Objective Value: 759 - %Gap: 17.49 - No. of Cycles: 29.00 - CPU Time(s): 17.17
# DISCARD

# %%
# Writing hyperparameter optimization results to a file

#f = open('dataset2x-2.pckl', 'wb')
#pickle.dump(hyperParameters, f)
#f.close()

# %%
# Hyperparameter runs for 3-change move

runs = 5

nSizes = [3]

initialProbs = [0.75, 0.85, 0.95]

initialLs = [100, 500, 1000]

alphas = [0.85, 0.90, 0.95]

gamas = [1.05, 1.1, 1.15]

hyperParameters = []

counter = 1

for nSize in nSizes:
    for initialProb in initialProbs:
        for initialL in initialLs:
            for alpha in alphas:
                for gama in gamas:
                    hp = []
                    gapSum = 0
                    isOK = True
                    
                    print("(" + str(counter) + ") nSize: " + str(nSize) + " - Acceptance: " + str(initialProb) + " - L: " + str(initialL) + " - alpha: " + str(alpha) + " - gama: " + str(gama))
                    for run in range(runs):
                        t1 = time.clock()

                        bestSolutions = []
                        totalIterations = []

                        initialTemp = setInitialTemp(initialProb, nSize)
                        
                        SA_GAP(initialTemp, initialL, alpha, gama, nSize, 1, bestSolutions, totalIterations)

                        t2 = time.clock()

                        bSolVal = calculateCost(bestSolutions[0])
                        G = 100 * (bSolVal-optimalObjective) / optimalObjective
                        nCycle = totalIterations[0]
                        timePassed = t2-t1

                        print(str(run) + ". Objective Value: " + str(bSolVal) + " - %Gap: " + "%.2f" %G + " - No. of Cycles: " + "%.2f" %nCycle +" - CPU Time(s): " + "%.2f" %timePassed)
                        
                        hp.append([bSolVal, G, nCycle, timePassed])
                        gapSum = gapSum + G
                        
                        if G > 2:
                            isOK = False
                            break
                        
                    if isOK:
                        hyperParameters.append([hp,counter])
                    else:
                        print("DISCARD")
                    
                    counter = counter + 1
                    print()
# Out:
# (1) nSize: 3 - Acceptance: 0.75 - L: 100 - alpha: 0.85 - gama: 1.05
# 0. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 108.00 - CPU Time(s): 15.51
# 1. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 105.00 - CPU Time(s): 13.81
# 2. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 104.00 - CPU Time(s): 13.23
# 3. Objective Value: 658 - %Gap: 1.86 - No. of Cycles: 98.00 - CPU Time(s): 10.94
# 4. Objective Value: 659 - %Gap: 2.01 - No. of Cycles: 115.00 - CPU Time(s): 22.35
# DISCARD
#
# (2) nSize: 3 - Acceptance: 0.75 - L: 100 - alpha: 0.85 - gama: 1.1
# 0. Objective Value: 658 - %Gap: 1.86 - No. of Cycles: 56.00 - CPU Time(s): 9.91
# 1. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 54.00 - CPU Time(s): 8.41
# 2. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 64.00 - CPU Time(s): 19.58
# 3. Objective Value: 666 - %Gap: 3.10 - No. of Cycles: 57.00 - CPU Time(s): 10.78
# DISCARD
#
# (3) nSize: 3 - Acceptance: 0.75 - L: 100 - alpha: 0.85 - gama: 1.15
# 0. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 47.00 - CPU Time(s): 20.36
# 1. Objective Value: 662 - %Gap: 2.48 - No. of Cycles: 45.00 - CPU Time(s): 15.58
# DISCARD
#
# (4) nSize: 3 - Acceptance: 0.75 - L: 100 - alpha: 0.9 - gama: 1.05
# 0. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 108.00 - CPU Time(s): 17.79
# 1. Objective Value: 658 - %Gap: 1.86 - No. of Cycles: 97.00 - CPU Time(s): 10.53
# 2. Objective Value: 661 - %Gap: 2.32 - No. of Cycles: 104.00 - CPU Time(s): 13.55
# DISCARD
#
# (5) nSize: 3 - Acceptance: 0.75 - L: 100 - alpha: 0.9 - gama: 1.1
# 0. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 69.00 - CPU Time(s): 30.17
# 1. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 57.00 - CPU Time(s): 10.81
# 2. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 66.00 - CPU Time(s): 22.74
# 3. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 60.00 - CPU Time(s): 13.60
# 4. Objective Value: 669 - %Gap: 3.56 - No. of Cycles: 52.00 - CPU Time(s): 7.41
# DISCARD
#
# (6) nSize: 3 - Acceptance: 0.75 - L: 100 - alpha: 0.9 - gama: 1.15
# 0. Objective Value: 660 - %Gap: 2.17 - No. of Cycles: 44.00 - CPU Time(s): 14.14
# DISCARD
#
# (7) nSize: 3 - Acceptance: 0.75 - L: 100 - alpha: 0.95 - gama: 1.05
# 0. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 113.00 - CPU Time(s): 19.72
# 1. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 103.00 - CPU Time(s): 13.97
# 2. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 118.00 - CPU Time(s): 26.96
# 3. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 98.00 - CPU Time(s): 10.45
# 4. Objective Value: 659 - %Gap: 2.01 - No. of Cycles: 97.00 - CPU Time(s): 9.91
# DISCARD
#
# (8) nSize: 3 - Acceptance: 0.75 - L: 100 - alpha: 0.95 - gama: 1.1
# 0. Objective Value: 663 - %Gap: 2.63 - No. of Cycles: 50.00 - CPU Time(s): 6.10
# DISCARD
#
# (9) nSize: 3 - Acceptance: 0.75 - L: 100 - alpha: 0.95 - gama: 1.15
# 0. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 50.00 - CPU Time(s): 29.71
# 1. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 53.00 - CPU Time(s): 45.01
# 2. Objective Value: 673 - %Gap: 4.18 - No. of Cycles: 39.00 - CPU Time(s): 7.49
# DISCARD
#
# (10) nSize: 3 - Acceptance: 0.75 - L: 500 - alpha: 0.85 - gama: 1.05
# 0. Objective Value: 659 - %Gap: 2.01 - No. of Cycles: 90.00 - CPU Time(s): 34.86
# DISCARD
#
# (11) nSize: 3 - Acceptance: 0.75 - L: 500 - alpha: 0.85 - gama: 1.1
# 0. Objective Value: 661 - %Gap: 2.32 - No. of Cycles: 44.00 - CPU Time(s): 14.81
# DISCARD
#
# (12) nSize: 3 - Acceptance: 0.75 - L: 500 - alpha: 0.85 - gama: 1.15
# 0. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 33.00 - CPU Time(s): 15.09
# 1. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 40.00 - CPU Time(s): 38.49
# 2. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 30.00 - CPU Time(s): 10.66
# 3. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 33.00 - CPU Time(s): 15.27
# 4. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 33.00 - CPU Time(s): 16.42
#
# (13) nSize: 3 - Acceptance: 0.75 - L: 500 - alpha: 0.9 - gama: 1.05
# 0. Objective Value: 663 - %Gap: 2.63 - No. of Cycles: 70.00 - CPU Time(s): 14.08
# DISCARD
#
# (14) nSize: 3 - Acceptance: 0.75 - L: 500 - alpha: 0.9 - gama: 1.1
# 0. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 53.00 - CPU Time(s): 34.19
# 1. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 46.00 - CPU Time(s): 18.27
# 2. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 47.00 - CPU Time(s): 20.14
# 3. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 41.00 - CPU Time(s): 11.75
# 4. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 42.00 - CPU Time(s): 12.85
#
# (15) nSize: 3 - Acceptance: 0.75 - L: 500 - alpha: 0.9 - gama: 1.15
# 0. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 36.00 - CPU Time(s): 22.99
# 1. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 35.00 - CPU Time(s): 19.97
# 2. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 34.00 - CPU Time(s): 17.37
# 3. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 33.00 - CPU Time(s): 15.45
# 4. Objective Value: 649 - %Gap: 0.46 - No. of Cycles: 39.00 - CPU Time(s): 33.89
#
# (16) nSize: 3 - Acceptance: 0.75 - L: 500 - alpha: 0.95 - gama: 1.05
# 0. Objective Value: 661 - %Gap: 2.32 - No. of Cycles: 64.00 - CPU Time(s): 10.84
# DISCARD
#
# (17) nSize: 3 - Acceptance: 0.75 - L: 500 - alpha: 0.95 - gama: 1.1
# 0. Objective Value: 662 - %Gap: 2.48 - No. of Cycles: 51.00 - CPU Time(s): 29.55
# DISCARD
#
# (18) nSize: 3 - Acceptance: 0.75 - L: 500 - alpha: 0.95 - gama: 1.15
# 0. Objective Value: 665 - %Gap: 2.94 - No. of Cycles: 41.00 - CPU Time(s): 45.56
# DISCARD
#
# (19) nSize: 3 - Acceptance: 0.75 - L: 1000 - alpha: 0.85 - gama: 1.05
# 0. Objective Value: 661 - %Gap: 2.32 - No. of Cycles: 48.00 - CPU Time(s): 9.49
# DISCARD
#
# (20) nSize: 3 - Acceptance: 0.75 - L: 1000 - alpha: 0.85 - gama: 1.1
# 0. Objective Value: 658 - %Gap: 1.86 - No. of Cycles: 36.00 - CPU Time(s): 14.46
# 1. Objective Value: 661 - %Gap: 2.32 - No. of Cycles: 40.00 - CPU Time(s): 19.55
# DISCARD
#
# (21) nSize: 3 - Acceptance: 0.75 - L: 1000 - alpha: 0.85 - gama: 1.15
# 0. Objective Value: 646 - %Gap: 0.00 - No. of Cycles: 36.00 - CPU Time(s): 45.27
# 1. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 29.00 - CPU Time(s): 18.14
# 2. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 33.00 - CPU Time(s): 29.32
# 3. Objective Value: 661 - %Gap: 2.32 - No. of Cycles: 35.00 - CPU Time(s): 39.57
# DISCARD
#
# (22) nSize: 3 - Acceptance: 0.75 - L: 1000 - alpha: 0.9 - gama: 1.05
# 0. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 59.00 - CPU Time(s): 15.42
# 1. Objective Value: 662 - %Gap: 2.48 - No. of Cycles: 48.00 - CPU Time(s): 9.35
# DISCARD
#
# (23) nSize: 3 - Acceptance: 0.75 - L: 1000 - alpha: 0.9 - gama: 1.1
# 0. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 45.00 - CPU Time(s): 32.75
# 1. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 41.00 - CPU Time(s): 22.62
# 2. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 42.00 - CPU Time(s): 24.73
# 3. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 42.00 - CPU Time(s): 23.44
# 4. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 42.00 - CPU Time(s): 23.94
#
# (24) nSize: 3 - Acceptance: 0.75 - L: 1000 - alpha: 0.9 - gama: 1.15
# 0. Objective Value: 649 - %Gap: 0.46 - No. of Cycles: 35.00 - CPU Time(s): 38.17
# 1. Objective Value: 659 - %Gap: 2.01 - No. of Cycles: 29.00 - CPU Time(s): 16.72
# DISCARD
#
# (25) nSize: 3 - Acceptance: 0.75 - L: 1000 - alpha: 0.95 - gama: 1.05
# 0. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 61.00 - CPU Time(s): 16.65
# 1. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 73.00 - CPU Time(s): 31.05
# 2. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 68.00 - CPU Time(s): 24.18
# 3. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 60.00 - CPU Time(s): 17.46
# 4. Objective Value: 660 - %Gap: 2.17 - No. of Cycles: 57.00 - CPU Time(s): 14.57
# DISCARD
#
# (26) nSize: 3 - Acceptance: 0.75 - L: 1000 - alpha: 0.95 - gama: 1.1
# 0. Objective Value: 648 - %Gap: 0.31 - No. of Cycles: 53.00 - CPU Time(s): 67.95
# 1. Objective Value: 679 - %Gap: 5.11 - No. of Cycles: 42.00 - CPU Time(s): 24.98
# DISCARD
#
# (27) nSize: 3 - Acceptance: 0.75 - L: 1000 - alpha: 0.95 - gama: 1.15
# 0. Objective Value: 670 - %Gap: 3.72 - No. of Cycles: 36.00 - CPU Time(s): 45.14
# DISCARD
#
# (28) nSize: 3 - Acceptance: 0.85 - L: 100 - alpha: 0.85 - gama: 1.05
# 0. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 110.00 - CPU Time(s): 18.92
# 1. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 103.00 - CPU Time(s): 13.00
# 2. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 112.00 - CPU Time(s): 17.58
# 3. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 97.00 - CPU Time(s): 9.18
# 4. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 97.00 - CPU Time(s): 10.46
#
# (29) nSize: 3 - Acceptance: 0.85 - L: 100 - alpha: 0.85 - gama: 1.1
# 0. Objective Value: 658 - %Gap: 1.86 - No. of Cycles: 61.00 - CPU Time(s): 13.49
# 1. Objective Value: 668 - %Gap: 3.41 - No. of Cycles: 49.00 - CPU Time(s): 5.30
# DISCARD
#
# (30) nSize: 3 - Acceptance: 0.85 - L: 100 - alpha: 0.85 - gama: 1.15
# 0. Objective Value: 659 - %Gap: 2.01 - No. of Cycles: 40.00 - CPU Time(s): 8.20
# DISCARD
#
# (31) nSize: 3 - Acceptance: 0.85 - L: 100 - alpha: 0.9 - gama: 1.05
# 0. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 105.00 - CPU Time(s): 13.81
# 1. Objective Value: 646 - %Gap: 0.00 - No. of Cycles: 97.00 - CPU Time(s): 9.60
# 2. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 97.00 - CPU Time(s): 10.27
# 3. Objective Value: 660 - %Gap: 2.17 - No. of Cycles: 107.00 - CPU Time(s): 13.87
# DISCARD
#
# (32) nSize: 3 - Acceptance: 0.85 - L: 100 - alpha: 0.9 - gama: 1.1
# 0. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 64.00 - CPU Time(s): 17.61
# 1. Objective Value: 671 - %Gap: 3.87 - No. of Cycles: 49.00 - CPU Time(s): 5.28
# DISCARD
#
# (33) nSize: 3 - Acceptance: 0.85 - L: 100 - alpha: 0.9 - gama: 1.15
# 0. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 45.00 - CPU Time(s): 14.29
# 1. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 53.00 - CPU Time(s): 40.80
# 2. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 45.00 - CPU Time(s): 16.12
# 3. Objective Value: 661 - %Gap: 2.32 - No. of Cycles: 49.00 - CPU Time(s): 24.65
# DISCARD
#
# (34) nSize: 3 - Acceptance: 0.85 - L: 100 - alpha: 0.95 - gama: 1.05
# 0. Objective Value: 664 - %Gap: 2.79 - No. of Cycles: 107.00 - CPU Time(s): 14.12
# DISCARD
#
# (35) nSize: 3 - Acceptance: 0.85 - L: 100 - alpha: 0.95 - gama: 1.1
# 0. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 72.00 - CPU Time(s): 37.81
# 1. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 72.00 - CPU Time(s): 37.59
# 2. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 69.00 - CPU Time(s): 28.23
# 3. Objective Value: 646 - %Gap: 0.00 - No. of Cycles: 78.00 - CPU Time(s): 72.95
# 4. Objective Value: 658 - %Gap: 1.86 - No. of Cycles: 66.00 - CPU Time(s): 28.30
#
# (36) nSize: 3 - Acceptance: 0.85 - L: 100 - alpha: 0.95 - gama: 1.15
# 0. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 53.00 - CPU Time(s): 55.43
# 1. Objective Value: 658 - %Gap: 1.86 - No. of Cycles: 53.00 - CPU Time(s): 56.72
# 2. Objective Value: 675 - %Gap: 4.49 - No. of Cycles: 47.00 - CPU Time(s): 24.80
# DISCARD
#
# (37) nSize: 3 - Acceptance: 0.85 - L: 500 - alpha: 0.85 - gama: 1.05
# 0. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 78.00 - CPU Time(s): 24.05
# 1. Objective Value: 658 - %Gap: 1.86 - No. of Cycles: 81.00 - CPU Time(s): 22.99
# 2. Objective Value: 659 - %Gap: 2.01 - No. of Cycles: 66.00 - CPU Time(s): 9.82
# DISCARD
#
# (38) nSize: 3 - Acceptance: 0.85 - L: 500 - alpha: 0.85 - gama: 1.1
# 0. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 49.00 - CPU Time(s): 20.43
# 1. Objective Value: 662 - %Gap: 2.48 - No. of Cycles: 34.00 - CPU Time(s): 5.75
# DISCARD
#
# (39) nSize: 3 - Acceptance: 0.85 - L: 500 - alpha: 0.85 - gama: 1.15
# 0. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 36.00 - CPU Time(s): 19.41
# 1. Objective Value: 662 - %Gap: 2.48 - No. of Cycles: 36.00 - CPU Time(s): 19.39
# DISCARD
#
# (40) nSize: 3 - Acceptance: 0.85 - L: 500 - alpha: 0.9 - gama: 1.05
# 0. Objective Value: 672 - %Gap: 4.02 - No. of Cycles: 62.00 - CPU Time(s): 8.26
# DISCARD
#
# (41) nSize: 3 - Acceptance: 0.85 - L: 500 - alpha: 0.9 - gama: 1.1
# 0. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 52.00 - CPU Time(s): 26.40
# 1. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 43.00 - CPU Time(s): 11.91
# 2. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 45.00 - CPU Time(s): 14.20
# 3. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 49.00 - CPU Time(s): 20.18
# 4. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 51.00 - CPU Time(s): 24.06
#
# (42) nSize: 3 - Acceptance: 0.85 - L: 500 - alpha: 0.9 - gama: 1.15
# 0. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 39.00 - CPU Time(s): 28.84
# 1. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 41.00 - CPU Time(s): 39.89
# 2. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 41.00 - CPU Time(s): 43.61
# 3. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 41.00 - CPU Time(s): 40.17
# 4. Objective Value: 648 - %Gap: 0.31 - No. of Cycles: 41.00 - CPU Time(s): 41.44
#
# (43) nSize: 3 - Acceptance: 0.85 - L: 500 - alpha: 0.95 - gama: 1.05
# 0. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 82.00 - CPU Time(s): 20.18
# 1. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 82.00 - CPU Time(s): 20.05
# 2. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 80.00 - CPU Time(s): 18.38
# 3. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 89.00 - CPU Time(s): 27.97
# 4. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 93.00 - CPU Time(s): 34.73
#
# (44) nSize: 3 - Acceptance: 0.85 - L: 500 - alpha: 0.95 - gama: 1.1
# 0. Objective Value: 667 - %Gap: 3.25 - No. of Cycles: 49.00 - CPU Time(s): 20.04
# DISCARD
#
# (45) nSize: 3 - Acceptance: 0.85 - L: 500 - alpha: 0.95 - gama: 1.15
# 0. Objective Value: 692 - %Gap: 7.12 - No. of Cycles: 41.00 - CPU Time(s): 37.58
# DISCARD
#
# (46) nSize: 3 - Acceptance: 0.85 - L: 1000 - alpha: 0.85 - gama: 1.05
# 0. Objective Value: 660 - %Gap: 2.17 - No. of Cycles: 61.00 - CPU Time(s): 14.59
# DISCARD
#
# (47) nSize: 3 - Acceptance: 0.85 - L: 1000 - alpha: 0.85 - gama: 1.1
# 0. Objective Value: 661 - %Gap: 2.32 - No. of Cycles: 37.00 - CPU Time(s): 13.12
# DISCARD
#
# (48) nSize: 3 - Acceptance: 0.85 - L: 1000 - alpha: 0.85 - gama: 1.15
# 0. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 29.00 - CPU Time(s): 14.84
# 1. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 36.00 - CPU Time(s): 37.42
# 2. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 29.00 - CPU Time(s): 14.75
# 3. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 34.00 - CPU Time(s): 28.61
# 4. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 31.00 - CPU Time(s): 19.28
#
# (49) nSize: 3 - Acceptance: 0.85 - L: 1000 - alpha: 0.9 - gama: 1.05
# 0. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 52.00 - CPU Time(s): 10.24
# 1. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 52.00 - CPU Time(s): 9.60
# 2. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 51.00 - CPU Time(s): 9.20
# 3. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 67.00 - CPU Time(s): 19.33
# 4. Objective Value: 661 - %Gap: 2.32 - No. of Cycles: 55.00 - CPU Time(s): 11.05
# DISCARD
#
# (50) nSize: 3 - Acceptance: 0.85 - L: 1000 - alpha: 0.9 - gama: 1.1
# 0. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 42.00 - CPU Time(s): 20.62
# 1. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 43.00 - CPU Time(s): 22.38
# 2. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 42.00 - CPU Time(s): 20.44
# 3. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 46.00 - CPU Time(s): 29.59
# 4. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 43.00 - CPU Time(s): 22.57
#
# (51) nSize: 3 - Acceptance: 0.85 - L: 1000 - alpha: 0.9 - gama: 1.15
# 0. Objective Value: 775 - %Gap: 19.97 - No. of Cycles: 17.00 - CPU Time(s): 3.67
# DISCARD
#
# (52) nSize: 3 - Acceptance: 0.85 - L: 1000 - alpha: 0.95 - gama: 1.05
# 0. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 78.00 - CPU Time(s): 32.30
# 1. Objective Value: 674 - %Gap: 4.33 - No. of Cycles: 54.00 - CPU Time(s): 10.49
# DISCARD
#
# (53) nSize: 3 - Acceptance: 0.85 - L: 1000 - alpha: 0.95 - gama: 1.1
# 0. Objective Value: 802 - %Gap: 24.15 - No. of Cycles: 25.00 - CPU Time(s): 4.86
# DISCARD
#
# (54) nSize: 3 - Acceptance: 0.85 - L: 1000 - alpha: 0.95 - gama: 1.15
# 0. Objective Value: 768 - %Gap: 18.89 - No. of Cycles: 22.00 - CPU Time(s): 6.25
# DISCARD
#
# (55) nSize: 3 - Acceptance: 0.95 - L: 100 - alpha: 0.85 - gama: 1.05
# 0. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 97.00 - CPU Time(s): 8.73
# 1. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 127.00 - CPU Time(s): 33.29
# 2. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 102.00 - CPU Time(s): 10.77
# 3. Objective Value: 665 - %Gap: 2.94 - No. of Cycles: 97.00 - CPU Time(s): 8.72
# DISCARD
#
# (56) nSize: 3 - Acceptance: 0.95 - L: 100 - alpha: 0.85 - gama: 1.1
# 0. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 51.00 - CPU Time(s): 5.79
# 1. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 66.00 - CPU Time(s): 19.94
# 2. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 59.00 - CPU Time(s): 10.93
# 3. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 70.00 - CPU Time(s): 28.60
# 4. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 68.00 - CPU Time(s): 23.97
#
# (57) nSize: 3 - Acceptance: 0.95 - L: 100 - alpha: 0.85 - gama: 1.15
# 0. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 45.00 - CPU Time(s): 13.62
# 1. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 46.00 - CPU Time(s): 15.47
# 2. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 45.00 - CPU Time(s): 13.67
# 3. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 48.00 - CPU Time(s): 19.95
# 4. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 45.00 - CPU Time(s): 13.69
#
# (58) nSize: 3 - Acceptance: 0.95 - L: 100 - alpha: 0.9 - gama: 1.05
# 0. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 97.00 - CPU Time(s): 8.72
# 1. Objective Value: 656 - %Gap: 1.55 - No. of Cycles: 97.00 - CPU Time(s): 8.82
# 2. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 97.00 - CPU Time(s): 8.68
# 3. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 98.00 - CPU Time(s): 9.09
# 4. Objective Value: 666 - %Gap: 3.10 - No. of Cycles: 97.00 - CPU Time(s): 8.74
# DISCARD
#
# (59) nSize: 3 - Acceptance: 0.95 - L: 100 - alpha: 0.9 - gama: 1.1
# 0. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 66.00 - CPU Time(s): 19.98
# 1. Objective Value: 658 - %Gap: 1.86 - No. of Cycles: 60.00 - CPU Time(s): 11.83
# 2. Objective Value: 659 - %Gap: 2.01 - No. of Cycles: 55.00 - CPU Time(s): 7.83
# DISCARD
#
# (60) nSize: 3 - Acceptance: 0.95 - L: 100 - alpha: 0.9 - gama: 1.15
# 0. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 45.00 - CPU Time(s): 13.60
# 1. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 53.00 - CPU Time(s): 38.82
# 2. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 47.00 - CPU Time(s): 17.62
# 3. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 49.00 - CPU Time(s): 22.82
# 4. Objective Value: 659 - %Gap: 2.01 - No. of Cycles: 45.00 - CPU Time(s): 13.66
# DISCARD
#
# (61) nSize: 3 - Acceptance: 0.95 - L: 100 - alpha: 0.95 - gama: 1.05
# 0. Objective Value: 658 - %Gap: 1.86 - No. of Cycles: 97.00 - CPU Time(s): 8.68
# 1. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 125.00 - CPU Time(s): 30.34
# 2. Objective Value: 657 - %Gap: 1.70 - No. of Cycles: 97.00 - CPU Time(s): 8.63
# 3. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 110.00 - CPU Time(s): 15.14
# 4. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 102.00 - CPU Time(s): 10.67
#
# (62) nSize: 3 - Acceptance: 0.95 - L: 100 - alpha: 0.95 - gama: 1.1
# 0. Objective Value: 765 - %Gap: 18.42 - No. of Cycles: 52.00 - CPU Time(s): 6.20
# DISCARD
#
# (63) nSize: 3 - Acceptance: 0.95 - L: 100 - alpha: 0.95 - gama: 1.15
# 0. Objective Value: 786 - %Gap: 21.67 - No. of Cycles: 42.00 - CPU Time(s): 9.36
# DISCARD
#
# (64) nSize: 3 - Acceptance: 0.95 - L: 500 - alpha: 0.85 - gama: 1.05
# 0. Objective Value: 659 - %Gap: 2.01 - No. of Cycles: 70.00 - CPU Time(s): 11.66
# DISCARD
#
# (65) nSize: 3 - Acceptance: 0.95 - L: 500 - alpha: 0.85 - gama: 1.1
# 0. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 43.00 - CPU Time(s): 11.78
# 1. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 50.00 - CPU Time(s): 21.82
# 2. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 49.00 - CPU Time(s): 20.00
# 3. Objective Value: 666 - %Gap: 3.10 - No. of Cycles: 34.00 - CPU Time(s): 5.69
# DISCARD
#
# (66) nSize: 3 - Acceptance: 0.95 - L: 500 - alpha: 0.85 - gama: 1.15
# 0. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 41.00 - CPU Time(s): 37.38
# 1. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 35.00 - CPU Time(s): 16.89
# 2. Objective Value: 646 - %Gap: 0.00 - No. of Cycles: 41.00 - CPU Time(s): 37.51
# 3. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 33.00 - CPU Time(s): 13.19
# 4. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 38.00 - CPU Time(s): 25.07
#
# (67) nSize: 3 - Acceptance: 0.95 - L: 500 - alpha: 0.9 - gama: 1.05
# 0. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 65.00 - CPU Time(s): 9.32
# 1. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 67.00 - CPU Time(s): 10.18
# 2. Objective Value: 662 - %Gap: 2.48 - No. of Cycles: 62.00 - CPU Time(s): 8.20
# DISCARD
#
# (68) nSize: 3 - Acceptance: 0.95 - L: 500 - alpha: 0.9 - gama: 1.1
# 0. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 49.00 - CPU Time(s): 19.94
# 1. Objective Value: 660 - %Gap: 2.17 - No. of Cycles: 46.00 - CPU Time(s): 15.26
# DISCARD
#
# (69) nSize: 3 - Acceptance: 0.95 - L: 500 - alpha: 0.9 - gama: 1.15
# 0. Objective Value: 660 - %Gap: 2.17 - No. of Cycles: 41.00 - CPU Time(s): 37.39
# DISCARD
#
# (70) nSize: 3 - Acceptance: 0.95 - L: 500 - alpha: 0.95 - gama: 1.05
# 0. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 95.00 - CPU Time(s): 36.85
# 1. Objective Value: 658 - %Gap: 1.86 - No. of Cycles: 96.00 - CPU Time(s): 38.60
# 2. Objective Value: 661 - %Gap: 2.32 - No. of Cycles: 79.00 - CPU Time(s): 17.46
# DISCARD
#
# (71) nSize: 3 - Acceptance: 0.95 - L: 500 - alpha: 0.95 - gama: 1.1
# 0. Objective Value: 800 - %Gap: 23.84 - No. of Cycles: 32.00 - CPU Time(s): 4.90
# DISCARD
#
# (72) nSize: 3 - Acceptance: 0.95 - L: 500 - alpha: 0.95 - gama: 1.15
# 0. Objective Value: 791 - %Gap: 22.45 - No. of Cycles: 35.00 - CPU Time(s): 16.85
# DISCARD
#
# (73) nSize: 3 - Acceptance: 0.95 - L: 1000 - alpha: 0.85 - gama: 1.05
# 0. Objective Value: 664 - %Gap: 2.79 - No. of Cycles: 58.00 - CPU Time(s): 12.62
# DISCARD
#
# (74) nSize: 3 - Acceptance: 0.95 - L: 1000 - alpha: 0.85 - gama: 1.1
# 0. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 43.00 - CPU Time(s): 22.37
# 1. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 47.00 - CPU Time(s): 32.39
# 2. Objective Value: 654 - %Gap: 1.24 - No. of Cycles: 42.00 - CPU Time(s): 20.43
# 3. Objective Value: 661 - %Gap: 2.32 - No. of Cycles: 42.00 - CPU Time(s): 20.42
# DISCARD
#
# (75) nSize: 3 - Acceptance: 0.95 - L: 1000 - alpha: 0.85 - gama: 1.15
# 0. Objective Value: 650 - %Gap: 0.62 - No. of Cycles: 36.00 - CPU Time(s): 37.12
# 1. Objective Value: 793 - %Gap: 22.76 - No. of Cycles: 17.00 - CPU Time(s): 3.63
# DISCARD
#
# (76) nSize: 3 - Acceptance: 0.95 - L: 1000 - alpha: 0.9 - gama: 1.05
# 0. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 64.00 - CPU Time(s): 16.65
# 1. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 71.00 - CPU Time(s): 23.13
# 2. Objective Value: 662 - %Gap: 2.48 - No. of Cycles: 57.00 - CPU Time(s): 11.99
# DISCARD
#
# (77) nSize: 3 - Acceptance: 0.95 - L: 1000 - alpha: 0.9 - gama: 1.1
# 0. Objective Value: 648 - %Gap: 0.31 - No. of Cycles: 53.00 - CPU Time(s): 56.33
# 1. Objective Value: 651 - %Gap: 0.77 - No. of Cycles: 46.00 - CPU Time(s): 29.23
# 2. Objective Value: 653 - %Gap: 1.08 - No. of Cycles: 46.00 - CPU Time(s): 29.30
# 3. Objective Value: 652 - %Gap: 0.93 - No. of Cycles: 46.00 - CPU Time(s): 29.29
# 4. Objective Value: 655 - %Gap: 1.39 - No. of Cycles: 49.00 - CPU Time(s): 38.82
#
# (78) nSize: 3 - Acceptance: 0.95 - L: 1000 - alpha: 0.9 - gama: 1.15
# 0. Objective Value: 668 - %Gap: 3.41 - No. of Cycles: 36.00 - CPU Time(s): 37.16
# DISCARD
#
# (79) nSize: 3 - Acceptance: 0.95 - L: 1000 - alpha: 0.95 - gama: 1.05
# 0. Objective Value: 763 - %Gap: 18.11 - No. of Cycles: 52.00 - CPU Time(s): 9.52
# DISCARD
#
# (80) nSize: 3 - Acceptance: 0.95 - L: 1000 - alpha: 0.95 - gama: 1.1
# 0. Objective Value: 786 - %Gap: 21.67 - No. of Cycles: 25.00 - CPU Time(s): 4.82
# DISCARD
#
# (81) nSize: 3 - Acceptance: 0.95 - L: 1000 - alpha: 0.95 - gama: 1.15
# 0. Objective Value: 797 - %Gap: 23.37 - No. of Cycles: 24.00 - CPU Time(s): 7.84
# DISCARD

# %%
# Writing hyperparameter optimization results to a file

#f = open('dataset2x-3.pckl', 'wb')
#pickle.dump(hyperParameters, f)
#f.close()

# %% [markdown]
# ### Examining the hyperparameter optimization results

# %%
# Loads the optimization results

f = open('dataset2x-2.pckl', 'rb')
hyperParameters2 = pickle.load(f)
f.close()

f = open('dataset2x-3.pckl', 'rb')
hyperParameters3 = pickle.load(f)
f.close()

# %%
print("Number of Configurations from 2-Change: " + str(len(hyperParameters2)))
print("Number of Configurations from 3-Change: " + str(len(hyperParameters3)))

print(hyperParameters2[0])
print(hyperParameters3[0])
# Out:
# Number of Configurations from 2-Change: 28
# Number of Configurations from 3-Change: 16
# [[[654, 1.238390092879257, 45, 13.657973738697706], [650, 0.6191950464396285, 45, 14.015205117781647], [657, 1.7027863777089782, 45, 13.887467985223111], [652, 0.9287925696594427, 48, 19.523433256177896], [649, 0.46439628482972134, 42, 9.196125792245994]], 6]
# [[[653, 1.08359133126935, 33, 15.087502908638271], [654, 1.238390092879257, 40, 38.49076919612526], [654, 1.238390092879257, 30, 10.66001620541283], [654, 1.238390092879257, 33, 15.26724867091525], [654, 1.238390092879257, 33, 16.42331841186933]], 12]

# %%
hyperParametersAvg2 = []
for i in range(int(len(hyperParameters2))):
    hyperParametersAvg2.append([[0,0,0,0],0])

for i in range(len(hyperParameters2)*5):
    hyperParametersAvg2[int(i/5)][1] = hyperParameters2[int(i/5)][1]
    for j in range(len(hyperParametersAvg2[int(i/5)][0])):
        hyperParametersAvg2[int(i/5)][0][j] = hyperParametersAvg2[int(i/5)][0][j] + hyperParameters2[int(i/5)][0][i%5][j]/5
        
        
hyperParametersAvg3 = []
for i in range(int(len(hyperParameters3))):
    hyperParametersAvg3.append([[0,0,0,0],0])

for i in range(len(hyperParameters3)*5):
    hyperParametersAvg3[int(i/5)][1] = hyperParameters3[int(i/5)][1]
    for j in range(len(hyperParametersAvg3[int(i/5)][0])):
        hyperParametersAvg3[int(i/5)][0][j] = hyperParametersAvg3[int(i/5)][0][j] + hyperParameters3[int(i/5)][0][i%5][j]/5
        
print(hyperParametersAvg2[0])

print(hyperParametersAvg3[0])
# Out:
# [[652.4000000000001, 0.9907120743034055, 45.0, 14.056041178025271], 6]
# [[653.8, 1.2074303405572755, 33.800000000000004, 19.18577107859219], 12]

# %% [markdown]
# Our main objective is minimizing both Gap percentage and CPU time. So first, I plot the Gap percentage penalties of each run and then plot the CPU times of eah run.

# %%
# Create random data with numpy
import numpy as np

x2 = []
x3 = []

hpGaps2 = []
for hp in hyperParametersAvg2:
    hpGaps2.append(hp[0][1])
    x2.append(hp[1])

hpGaps3 = []
for hp in hyperParametersAvg3:
    hpGaps3.append(hp[0][1])
    x3.append(hp[1])


# Create a trace
trace = go.Scatter(
    x = x2,
    y = hpGaps2,
    mode = 'markers',
    name = '2-Changes'
)

trace2 = go.Scatter(
    x = x3,
    y = hpGaps3,
    mode = 'markers',
    name = '3-Changes'
)

data = [trace, trace2]

layout = go.Layout(
    title='Gap Percentage of Runs',
    xaxis=dict(
        title='Run Number',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    ),
    yaxis=dict(
        title='Gap Percentage',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    )
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='Gap Percentage of Runs')

#py.iplot(data, filename='basic-scatter')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~suyunu/18.embed" height="525px" width="100%"></iframe>

# %%
# Create random data with numpy
import numpy as np

x2 = []
x3 = []

hpTime2 = []
for hp in hyperParametersAvg2:
    hpTime2.append(hp[0][3])
    x2.append(hp[1])

hpTime3 = []
for hp in hyperParametersAvg3:
    hpTime3.append(hp[0][3])
    x3.append(hp[1])


# Create a trace
trace = go.Scatter(
    x = x2,
    y = hpTime2,
    mode = 'markers',
    name = '2-Changes'
)

trace2 = go.Scatter(
    x = x3,
    y = hpTime3,
    mode = 'markers',
    name = '3-Changes'
)

data = [trace, trace2]

layout = go.Layout(
    title='CPU Times of Runs',
    xaxis=dict(
        title='Run Number',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    ),
    yaxis=dict(
        title='CPU Times (s)',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    )
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='CPU Time of Runs')

#py.iplot(data, filename='basic-scatter')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~suyunu/20.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# These are all actaully good results, because we have already discarded the parameters which gives gap% worse than %2. However we want the best results, so let's also take parameters with gap% greater than 1.
#
# However CPU time graph is more scattered and it is hard to observe it. So lets cut runs from 15 seconds. We will plot runs that executed in less than 15 seconds and more than 15 seconds in different colors.
#
# Then we will plot those two graphs together.

# %%
hpG2 = []
hpT2 = []
hpGx2 = []
hpTx2 = []
xx2 = []
xxx2 = []
for i in range(len(hyperParametersAvg2)):
    if hpGaps2[i] < 1 and hpTime2[i] < 15:
        hpG2.append(hpGaps2[i])
        hpT2.append(hpTime2[i])
        xx2.append(x2[i])
    elif hpGaps2[i] < 1 and hpTime2[i] >= 15:
        hpGx2.append(hpGaps2[i])
        hpTx2.append(hpTime2[i])
        xxx2.append(x2[i])
        
hpG3 = []
hpT3 = []
hpGx3 = []
hpTx3 = []
xx3 = []
xxx3 = []
for i in range(len(hyperParametersAvg3)):
    if hpGaps3[i] < 1 and hpTime3[i] < 15:
        hpG3.append(hpGaps3[i])
        hpT3.append(hpTime3[i])
        xx3.append(x3[i])
    elif hpGaps3[i] < 1 and hpTime3[i] >= 15:
        hpGx3.append(hpGaps3[i])
        hpTx3.append(hpTime3[i])
        xxx3.append(x3[i])
        
print("Change2 - Gap% < 1 and Time < 15: " + str(len(hpG2)))
print("Change3 - Gap% < 1 and Time < 15: " + str(len(hpG3)))
print("Change2 - Gap% < 1 and Time > 15: " + str(len(hpGx2)))
print("Change3 - Gap% < 1 and Time > 15: " + str(len(hpGx3)))

        
trace = go.Scatter(
    x = xx2,
    y = hpG2,
    mode = 'markers',
    name = '2-Ch G<1',
    line = dict(color = ('rgb(0, 0, 255)'))
)

trace2 = go.Scatter(
    x = xx2,
    y = hpT2,
    mode = 'markers',
    name = '2-Ch T<15',
    line = dict(color = ('rgb(0, 0, 255)'))
)

trace3 = go.Scatter(
    x = xx3,
    y = hpG3,
    mode = 'markers',
    name = '3-Ch G<1',
    line = dict(color = ('rgb(255, 0, 255)'))
)

trace4 = go.Scatter(
    x = xx3,
    y = hpT3,
    mode = 'markers',
    name = '3-Ch T<15',
    line = dict(color = ('rgb(255, 0, 255)'))
)

trace5 = go.Scatter(
    x = xxx2,
    y = hpGx2,
    mode = 'markers',
    name = '2-Ch G<1',
    line = dict(color = ('rgb(255, 255, 0)'))
)

trace6 = go.Scatter(
    x = xxx2,
    y = hpTx2,
    mode = 'markers',
    name = '2-Ch T>15',
    line = dict(color = ('rgb(255, 255, 0)'))
)

trace7 = go.Scatter(
    x = xxx3,
    y = hpGx3,
    mode = 'markers',
    name = '3-Ch G<1',
    line = dict(color = ('rgb(255, 0, 0)'))
)

trace8 = go.Scatter(
    x = xxx3,
    y = hpTx3,
    mode = 'markers',
    name = '3-Ch T>15',
    line = dict(color = ('rgb(255, 0, 0)'))
)


data = [trace, trace2, trace3, trace4, trace5, trace6, trace7, trace8]

layout = go.Layout(
    title='Gap and Time of Runs',
    xaxis=dict(
        title='Run Number',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    ),
    yaxis=dict(
        title='Gaps and CPU Times',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    )
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='Gap and Time of Runs')
# Out:
# Change2 - Gap% < 1 and Time < 15: 2
# Change3 - Gap% < 1 and Time < 15: 0
# Change2 - Gap% < 1 and Time > 15: 9
# Change3 - Gap% < 1 and Time > 15: 3
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~suyunu/22.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# As a last thing, I sorted the above data with increasing Gap%

# %%
hpSort = []
for i in range(len(hpG2)):
    hpSort.append([hpG2[i], hpT2[i], xx2[i], 2])
for i in range(len(hpG3)):
    hpSort.append([hpG3[i], hpT3[i], xx3[i], 3])
for i in range(len(hpGx2)):
    hpSort.append([hpGx2[i], hpTx2[i], xxx2[i], 2])
for i in range(len(hpGx3)):
    hpSort.append([hpGx3[i], hpTx3[i], xxx3[i], 3])

print(len(hpSort))
hpSort.sort()
for i in range(len(hpSort)):
    print(str(i+1) + ". " + str(hpSort[i]))
# Out:
# 14
# 1. [0.43343653250773995, 19.999290628001223, 8, 2]
# 2. [0.4953560371517028, 33.659829815510335, 24, 2]
# 3. [0.6811145510835913, 20.40611341497674, 23, 2]
# 4. [0.7739938080495357, 26.006113652013667, 66, 3]
# 5. [0.7739938080495357, 52.93161781931703, 79, 2]
# 6. [0.804953560371517, 41.82187628024539, 51, 2]
# 7. [0.8978328173374613, 18.85205335065275, 39, 2]
# 8. [0.8978328173374613, 36.59149251378694, 77, 3]
# 9. [0.9287925696594427, 15.280272892515494, 57, 3]
# 10. [0.9287925696594428, 13.815296297920487, 59, 2]
# 11. [0.9597523219814241, 19.93221562601602, 14, 2]
# 12. [0.9907120743034055, 14.056041178025271, 6, 2]
# 13. [0.9907120743034055, 34.33376442418048, 77, 2]
# 14. [0.9907120743034056, 22.581284446872722, 41, 2]

# %% [markdown]
# As we can observe the first 2 parametrization gives very promissing results. Especially the first one gives both a very good gap percentage and a very good timing. So, let's write their parameter settings.
#
# * (8) nSize: 2 - Acceptance: 0.75 - L: 100 - alpha: 0.95 - gama: 1.1
#   * Expected Values:
#     * Objective Value: 648.80
#     * %Gap: 0.43
#     * No. of Cycles: 66.40
#     * CPU Time(s): 20.00
#
# * (24) nSize: 2 - Acceptance: 0.75 - L: 1000 - alpha: 0.9 - gama: 1.15
#   * Expected Values:
#     * Objective Value: 649.20
#     * %Gap: 0.49
#     * No. of Cycles: 33.60
#     * CPU Time(s): 33.66

# %% [markdown]
# ### Main Solver
#
# This is the main solver of the code. We will run the algorithm with both of our chosen parameters twice, total of four runs. Then we will take the best solutions among four solution.

# %%
params1 = [2, 0.75, 100, 0.95, 1.1]
params2 = [2, 0.75, 1000, 0.9, 1.15]

# Start Timer
t1 = time.clock()

# Solve twice with first parameters

# Neighborhood search replace size
nSize = params1[0]

# How many times to reheat
nReheat = 2

initialTemp = setInitialTemp(params1[1], nSize)
initialL = params1[2]
alpha = params1[3]
gama = params1[4]
reheated = True
bestSolutions = []
totalIterations = []

SA_GAP(initialTemp, initialL, alpha, gama, nSize, nReheat, bestSolutions, totalIterations)

# Solve twice with second parameters


nSize = params2[0]
nReheat = 2
initialTemp = setInitialTemp(params2[1], nSize)
initialL = params2[2]
alpha = params2[3]
gama = params2[4]
reheated = True
SA_GAP(initialTemp, initialL, alpha, gama, nSize, nReheat, bestSolutions, totalIterations)


# Stop Timer
t2 = time.clock()
# Out:
# Objective Value: 1699 - %Gap: 0.06 - No. of Cycles: 73.00 - CPU Time(s): 104.29
# Objective Value: 1698 - %Gap: 0.00 - No. of Cycles: 78.00 - CPU Time(s): 168.52
# Objective Value: 1700 - %Gap: 0.12 - No. of Cycles: 36.00 - CPU Time(s): 103.57
# Objective Value: 1701 - %Gap: 0.18 - No. of Cycles: 36.00 - CPU Time(s): 99.66

# %% [markdown]
# ### Results
#
# This is the output part. You can observe the best solution of the previously run code.

# %%
bSol = bestSolutions[0]
bSolVal = calculateCost(bestSolutions[0])
for sol in bestSolutions:
    if bSolVal > calculateCost(sol):
        bSolVal = calculateCost(sol)
        bSol = sol

        
solDict = {}
print("Solution:")
for i in range(len(bSol)):
    if bSol[i]+1 not in solDict:
        solDict[bSol[i]+1] = [i+1]
    else:
        solDict[bSol[i]+1].append(i+1)

for i in range(m):
    print(str(i+1) + ": " + str(solDict[i+1]))
print()

print("Objective Value:")
print(bSolVal)
print()

print("%Gap:")
G = 100 * (bSolVal-optimalObjective) / optimalObjective
print("%.2f" %G)
print()

print("No. of Cycles: (Total of " + str(len(bestSolutions)) + " runs)")
nCycle = sum(totalIterations)
print("%.2f" %nCycle)
print()

print("CPU Time (s): (Total of " + str(len(bestSolutions)) + " runs)")
timePassed = (t2-t1)
print("%.2f" %timePassed)
# Out:
# Solution:
# 1: [6, 13, 17, 18, 21, 23, 29, 41, 47, 49, 51, 68, 73, 79, 81, 96]
# 2: [4, 26, 27, 34, 36, 46, 50, 60, 65, 69, 72, 76, 84, 88, 93, 94, 98]
# 3: [10, 14, 16, 25, 28, 30, 32, 33, 35, 37, 55, 59, 62, 67, 70, 71, 75, 78, 85, 90, 92, 100]
# 4: [1, 3, 5, 7, 9, 12, 19, 22, 24, 31, 42, 48, 52, 53, 56, 57, 58, 61, 63, 80, 82, 83, 87, 95, 99]
# 5: [2, 8, 11, 15, 20, 38, 39, 40, 43, 44, 45, 54, 64, 66, 74, 77, 86, 89, 91, 97]
#
# Objective Value:
# 1698
#
# %Gap:
# 0.00
#
# No. of Cycles: (Total of 4 runs)
# 223.00
#
# CPU Time (s): (Total of 4 runs)
# 482.12
